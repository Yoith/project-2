# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import xmltodict
import json

# %%
bgg = pd.read_csv("data/BGG100.csv", encoding = 'ISO-8859-1')

bgg
# Out:
#     Rank  Rating                               Name  \
# 0      1   8.511                        Gloomhaven
# 1      2   8.442          Pandemic Legacy: Season 1
# 2      3   8.418                  Brass: Birmingham
# 3      4   8.273                  Terraforming Mars
# 4      5   8.262  Twilight Imperium: Fourth Edition
# ..   ...     ...                                ...
# 95    96   7.529                   The Isle of Cats
# 96    97   7.528                 Russian Railroads
# 97    98   7.526                 Tigris & Euphrates
# 98    99   7.516                           Decrypto
# 99   100   7.512                             Trajan
#
#                                              Subtitle  Year  MinPlayers  \
# 0   Vanquish monsters with strategic cardplay. Ful...  2017           1
# 1   Mutating diseases are spreading around the wor...  2015           2
# 2   Build networks, grow industries, and navigate ...  2018           2
# 3   Compete with rival CEOs to make Mars habitable...  2016           1
# 4   Build an intergalactic empire through trade, r...  2017           3
# ..                                                ...   ...         ...
# 95  Rescue as many island cats as you can before L...  2019           1
# 96  Acquire locomotives & industry, build track, a...  2013           2
# 97  Keep your Mesopotamian civilisation in perfect...  1997           2
# 98  Decipher your opponents' code before they deci...  2018           3
# 99  Manage and rule all aspects of Ancient Rome wi...  2011           2
#
#     MaxPlayers BestPlayers  MinPlayTime  MaxPlayTime  MinAge  Weight  \
# 0            4           3           60          120      14    3.87
# 1            4           4           60           60      13    2.83
# 2            4        3, 4           60          120      14    3.90
# 3            5           3          120          120      12    3.24
# 4            6           6          240          480      14    4.26
# ..         ...         ...          ...          ...     ...     ...
# 95           4           3           60           90       8    2.31
# 96           4           4           90          120      12    3.41
# 97           4           4           90           90      12    3.51
# 98           8        4, 6           15           45      12    1.80
# 99           4           4           60          120      12    3.65
#
#                    Type
# 0   Strategy,  Thematic
# 1   Strategy,  Thematic
# 2             Strategy
# 3             Strategy
# 4   Strategy,  Thematic
# ..                  ...
# 95    Family,  Strategy
# 96             Strategy
# 97             Strategy
# 98                Party
# 99             Strategy
#
# [100 rows x 13 columns]

# %% [markdown]
# # BGG Information

# %%
bgg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rank         100 non-null    int64
#  1   Rating       100 non-null    float64
#  2   Name         100 non-null    object
#  3   Subtitle     100 non-null    object
#  4   Year         100 non-null    int64
#  5   MinPlayers   100 non-null    int64
#  6   MaxPlayers   100 non-null    int64
#  7   BestPlayers  97 non-null     object
#  8   MinPlayTime  100 non-null    int64
#  9   MaxPlayTime  100 non-null    int64
#  10  MinAge       100 non-null    int64
#  11  Weight       100 non-null    float64
#  12  Type         100 non-null    object
# dtypes: float64(2), int64(7), object(4)
# memory usage: 10.3+ KB

# %% [markdown]
# ### Number of columns

# %%
n_columns = bgg.shape[1]

print(f"The number of columns is {n_columns}")
# Out:
# The number of columns is 13

# %% [markdown]
# ### Number of rows

# %%
n_rows = bgg.shape[0]

print(f"The number of rows is {n_rows}")
# Out:
# The number of rows is 100

# %% [markdown]
# #### Modifying the column names

# %%
bgg.columns = [i.lower().replace(" ", "_").strip() for i in bgg.columns]

bgg.columns
# Out:
# Index(['rank', 'rating', 'name', 'subtitle', 'year', 'minplayers',
#        'maxplayers', 'bestplayers', 'minplaytime', 'maxplaytime', 'minage',
#        'weight', 'type'],
#       dtype='object')

# %% [markdown]
# ### Amount of Null Values per column

# %%
pd.isna(bgg).sum()
# Out:
# rank           0
# rating         0
# name           0
# subtitle       0
# year           0
# minplayers     0
# maxplayers     0
# bestplayers    3
# minplaytime    0
# maxplaytime    0
# minage         0
# weight         0
# type           0
# dtype: int64

# %% [markdown]
# ### Extracting the Top 10 games

# %%
top_games = bgg["name"].head(10)

print(top_games)
# Out:
# 0                                      Gloomhaven
# 1                        Pandemic Legacy: Season 1
# 2                                Brass: Birmingham
# 3                                Terraforming Mars
# 4                Twilight Imperium: Fourth Edition
# 5                     Gloomhaven: Jaws of the Lion
# 6                                     Gaia Project
# 7                             Star Wars: Rebellion
# 8    Through the Ages: A New Story of Civilization
# 9                  War of the Ring: Second Edition
# Name: name, dtype: object

# %% [markdown]
# ## Extracting additional information of the top 10 games, from the API

# %% [markdown]
# ### Gloomhaven

# %%
url = "https://api.geekdo.com/xmlapi/boardgame/174430/"

# In this first case I'm taking the url from the first game in 
# the ranking, "Gloomhaven", to find it I made a query searching this
# name in this url = https://boardgamegeek.com/xmlapi/search?search=Gloomhaven
# that gave me the id of the game "174430"

res = requests.get(xml_url)

res

# After find the game I realized the request and name it res, the code 200 let me continue
# Out:
# <Response [200]>

# %%
xml_data = res.content

xml_data

# After it I printed the content inside "res" the problem was that
# the information was in xml, not in html
# Out:
# b'<boardgames termsofuse="https://boardgamegeek.com/xmlapi/termsofuse">\n\t\t\t\t\t<boardgame objectid="174430">\n\t\t\t<yearpublished>2017</yearpublished>\n\t\t\t<minplayers>1</minplayers>\n\t\t\t<maxplayers>4</maxplayers>\n\t\t\t<playingtime>120</playingtime>\n\t\t\t<minplaytime>60</minplaytime>\n\t\t\t<maxplaytime>120</maxplaytime>\n\t\t\t<age>14</age>\n\n\t\t\t\t\t\t\t<name primary="true" sortindex="1">Gloomhaven</name>\n\t\t\t\t\t\t\t<name  sortindex="1">Gloomhaven, aventures \xc3\xa0 Havrenuit</name>\n\t\t\t\t\t\t\t<name  sortindex="1">Gloomhaven: \xd0\x9c\xd1\x80\xd0\xb0\xd1\x87\xd0\xbd\xd0\xb0\xd1\x8f \xd0\x93\xd0\xb0\xd0\xb2\xd0\xb0\xd0\xbd\xd1\x8c</name>\n\t\t\t\t\t\t\t<name  sortindex="1">Hom\xc3\xa1lyr\xc3\xa9v</name>\n\t\t\t\t\t\t\t<name  sortindex="1">\xe3\x82\xb0\xe3\x83\xab\xe3\x83\xbc\xe3\x83\xa0\xe3\x83\x98\xe3\x82\xa4\xe3\x83\xb4\xe3\x83\xb3</name>\n\t\t\t\t\t\t\t<name  sortindex="1">\xe5\xb9\xbd\xe6\xb8\xaf\xe8\xbf\xb7\xe5\x9f\x8e</name>\n\t\t\t\t\t\t\t<name  sortindex="1">\xea\xb8\x80\xeb\xa3\xb8\xed\x97\xa4\xec\x9d\xb4\xeb\xb8\x90</name>\n\t\t\t\t\t\t\t\t\t\n\t\t\t<description>This page does not exist. You can edit this page to create it.</description>\n\n\t\t\t\t\t\t\t<thumbnail>https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__thumb/img/veqFeP4d_3zNhFc3GNBkV95rBEQ=/fit-in/200x150/filters:strip_icc()/pic2437871.jpg</thumbnail>\n\t\t\t\thttps://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__original/img/7d-lj5Gd1e8PFnD97LYFah2c45M=/0x0/filters:format(jpeg)/pic2437871.jpg\n\t\t\t\t\t\t\n\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepublisher objectid="27425">Cephalofair Games</boardgamepublisher>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgameaccessory objectid="334735">Gloomhaven: reDrewno Insert</boardgameaccessory>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<cardset objectid="87588"></cardset>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="299749">#105: Blue Lagoon review; Proving Grounds &amp;amp; Aerion</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="205680">#45: Six-Player Six Pack; Las Vegas on tap; Barcelona; Mystic Vale; Betrayal at the Brewery on the Hill</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="224723">#5: Year in Review 2017</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="233238">#6: Today&#039;s Theme: Pronunciation</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="286111">#63: Hype Men</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="234283">#8: Just Deserts</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="271314">005 \xe2\x80\x93 Emergent Narrative &amp;amp; Storytelling in Board Games</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="272690">007 \xe2\x80\x93 Health Mechanics in Board and Card Games \xe2\x80\x93 Part 2</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="275973">012 \xe2\x80\x93 Co-Op Mechanics Part 2 \xe2\x80\x93 Fighting the Alpha Player Problem, Creating Team Decisions and Adding Tension</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="281827">017 \xe2\x80\x93 Ending Games using Fatigue &amp;amp; Exhaustion Mechanics</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="283457">018 \xe2\x80\x93 Artificial Intelligence in Board Games \xe2\x80\x93 Part 1</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="284469">019 \xe2\x80\x93 Artificial Intelligence in Board Games \xe2\x80\x93 Part 2</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcastepisode objectid="288361">022 \xe2\x80\x93 The one thing you need to know as a Game Designer</boardgamepodcastepisode>\n\t\t\t\t\t\t\t\t\t\t\t\t\t\t\t<boardgamepodcas ...

# %%
soup = BeautifulSoup(xml_data, "xml")

# I continued with the process using the library Soup to made it more
# readable

soup
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <boardgames termsofuse="https://boardgamegeek.com/xmlapi/termsofuse">
# <boardgame objectid="174430">
# <yearpublished>2017</yearpublished>
# <minplayers>1</minplayers>
# <maxplayers>4</maxplayers>
# <playingtime>120</playingtime>
# <minplaytime>60</minplaytime>
# <maxplaytime>120</maxplaytime>
# <age>14</age>
# <name primary="true" sortindex="1">Gloomhaven</name>
# <name sortindex="1">Gloomhaven, aventures à Havrenuit</name>
# <name sortindex="1">Gloomhaven: Мрачная Гавань</name>
# <name sortindex="1">Homályrév</name>
# <name sortindex="1">グルームヘイヴン</name>
# <name sortindex="1">幽港迷城</name>
# <name sortindex="1">글룸헤이븐</name>
# <description>This page does not exist. You can edit this page to create it.</description>
# <thumbnail>https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__thumb/img/veqFeP4d_3zNhFc3GNBkV95rBEQ=/fit-in/200x150/filters:strip_icc()/pic2437871.jpg</thumbnail>
# https://cf.geekdo-images.com/sZYp_3BTDGjh2unaZfZmuA__original/img/7d-lj5Gd1e8PFnD97LYFah2c45M=/0x0/filters:format(jpeg)/pic2437871.jpg
# <boardgamepublisher objectid="27425">Cephalofair Games</boardgamepublisher>
# <boardgameaccessory objectid="334735">Gloomhaven: reDrewno Insert</boardgameaccessory>
# <cardset objectid="87588"/>
# <boardgamepodcastepisode objectid="299749">#105: Blue Lagoon review; Proving Grounds &amp;amp; Aerion</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid
# <boardgamefamily objectid="5615">Creatures: Monsters</boardgamefamily>
# <boardgameexpansion objectid="365186">The Crimson Scales</boardgameexpansion>
# <boardgameexpansion objectid="367749">The Crimson Scales: Class Pack Add-on</boardgameexpansion>
# <boardgameexpansion objectid="367751">The Crimson Scales: Trail of Ashes</boardgameexpansion>
# <boardgamemechanic objectid="2854">Critical Hits and Failures</boardgamemechanic>
# <boardgamefamily objectid="8374">Crowdfunding: Kickstarter</boardgamefamily>
# <boardgamepodcastepisode objectid="161551">Cult of the New Board Game Podcast Episode 001</boardgamepodcastepisode>
# <boardgamedeveloper objectid="108338">Marcel Cwertetschka-Mattasits</boardgamedeveloper>
# <boardgameversion objectid="482203">Czech edition</boardgameversion>
# <boardgamemechanic objectid="3004">Deck Construction</boardgamemechanic>
# <boardgamepodcastepisode objectid="268664">Deep Sea Adventure | Gloomhaven | Century: Eastern Wonders</boardgamepodcastepisode>
# <boardgamefamily objectid="77349">Digital Implementations: Steam</boardgamefamily>
# <boardgamefamily objectid="73596">Digital Implementations: TableTop Simulator Mod (TTS)</boardgamefamily>
# <boardgamepodcastepisode objectid="341862">E5 | Games | Gloomhaven Starting Classes</boardgamepodcastepisode>
# <boardgameartist objectid="77084">Alexandr Elichev</boardgameartist>
# <boardgameversion objectid="479734">English edition, fifth printing</boardgameversion>
# <boardgameversion objectid="331120">English edition, first printing</boardgameversion>
# <boardgameversion objectid="451774">English edition, fourth printing</boardgameversion>
# <boardgameversion objectid="591864">English edition, ninth printing</boardgameversion>
# <boardgameversion objectid="351462">English edition, second printing</boardgameversion>
# <boardgameversion objectid="384592">English edition, second printing (with Solo Scenarios)</boardgameversion>
# <boardgameversion objectid="520054">English edition, sixth printing</boardgameversion>
# <boardgameversion objectid="481236">English edition, third printing</boardgameversion>
# <boardgameversion objectid="268248">English miniatures edition</boardgameversion>
# <boardgameversion objectid="331119">English standees edition</boardgameversion>
# <boardgamepodcastepisode objectid="307618">Ep 14- Build A 3 Game Collection</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="343600">Ep 22- The Tabletop Sessions Awards 2019</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="358731">Ep 26- Top 3 Co-Op Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="227613">Ep 3 - Photosynthesis Review and Party Poppers</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="483387">Ep 36- Gloomhaven VS Frosthaven</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="486268">Ep 37- Happy Soviet Traitor Day!</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="286288">Ep 8- The Root Giveaway &amp;amp; Top 3 Favorite Designers</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="236787">Ep. 04 - Charterstone Review</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="162515">Episide 17: Bonsai!</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="227750">Episode #26: Conventional Wisdom</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="227738">Episode #38: Two Player Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="199515">Episode 105 -- The Jay Andres Project</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="298162">Episode 106 :: Best Boardgames - Brawling Brothers Blend 2019</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="161347">Episode 11: Isaac Childres interview - Gloomhaven, Nations the Dice Game, Castles of Burgundy</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="334192">Episode 120 :: Top 20 Board Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="336009">Episode 121 :: Noel &amp;amp; Jordan's Top 10 Board Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="303141">Episode 13 - Legacy Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="362638">Episode 132 :: The Brawlers Blend 2020</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="233976">Episode 14 - Santa Maria, Calimala, Clans of Caledonia, Heaven &amp;amp; Ale, Dinosaur Island and more!</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid
boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="196233">Episode Four - Gloomhaven, Railroad Revolution, Unlock!</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="189644">Epside 35 :: The Others + On The Couch with Josh and Brandon</boardgamepodcastepisode>
# <boardgamecategory objectid="1020">Exploration</boardgamecategory>
# <boardgamecategory objectid="1010">Fantasy</boardgamecategory>
# <boardgamepublisher objectid="22380">Feuerland Spiele</boardgamepublisher>
# <boardgamecategory objectid="1046">Fighting</boardgamecategory>
# <boardgameversion objectid="475996">French edition</boardgameversion>
# <boardgameintegration objectid="295770">Frosthaven</boardgameintegration>
# <boardgamepublisher objectid="15605">Galápagos Jogos</boardgamepublisher>
# <boardgamefamily objectid="45610">Game: Gloomhaven</boardgamefamily>
# <boardgamepublisher objectid="40478">Games Warehouse</boardgamepublisher>
# <boardgamepublisher objectid="8820">Gém Klub Kft.</boardgamepublisher>
# <boardgameversion objectid="399953">German edition, first printing</boardgameversion>
# <boardgameversion objectid="466963">German edition, second printing</boardgameversion>
# <boardgameversion objectid="596972">German edition, third printing</boardgameversion>
# <videogamebg objectid="261209">Gloomhaven</videogamebg>
# <boardgamepodcastepisode objectid="495586">Gloomhaven</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="243759">Gloomhaven Brief Expedition</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="351013">Gloomhaven, Cities: Skylines, Ark(ham) of the Covenant Hotel - Boards &amp;amp; Swords #150</boardgamepodcastepisode>
# <boardgameaccessory objectid="289347">Gloomhaven: Adventure Tokens – Altar</boardgameaccessory>
# <boardgameaccessory objectid="306515">Gloomhaven: Adventure Tokens – Barrel</boardgameaccessory>
# <boardgameaccessory objectid="289346">Gloomhaven: Adventure Tokens – Bear Trap</boardgameaccessory>
# <boardgameaccessory objectid="289348">Gloomhaven: Adventure Tokens – Bookcase</boardgameaccessory>
# <boardgameaccessory objectid="289343">Gloomhaven: Adventure Tokens – Boulder</boardgameaccessory>
# <boardgameaccessory objectid="306373">Gloomhaven: Adventure Tokens – Bush</boardgameaccessory>
# <boardgameaccessory objectid="288415">Gloomhaven: Adventure Tokens – Cabinet</boardgameaccessory>
# <boardgameaccessory objectid="289344">Gloomhaven: Adventure Tokens – Chest</boardgameaccessory>
# <boardgameaccessory objectid="306378">Gloomhaven: Adventure Tokens – Crate</boardgameaccessory>
# <boardgameaccessory objectid="306513">Gloomhaven: Adventure Tokens – Crystal</boardgameaccessory>
# <boardgameaccessory objectid="289345">Gloomhaven: Adventure Tokens – Door</boardgameaccessory>
# <boardgameaccessory objectid="289349">Gloomhaven: Adventure Tokens – Fountain</boardgameaccessory>
# <boardgameaccessory objectid="288414">Gloomhaven: Adventure Tokens – Log</boardgameaccessory>
# <boardgameaccessory objectid="289350">Gloomhaven: Adventure Tokens – Nest</boardgameaccessory>
# <boardgameaccessory objectid="288418">Gloomhaven: Adventure Tokens – Poison Gas</boardgameaccessory>
# <boardgameaccessory objectid="288420">Gloomhaven: Adventure Tokens – Pressure Plate</boardgameaccessory>
# <boardgameaccessory objectid="306376">Gloomhaven: Adventure Tokens – Rock Column</boardgameaccessory>
# <boardgameaccessory objectid="289342">Gloomhaven: Adventure Tokens – Rubble</boardgameaccessory>
# <boardgameaccessory objectid="306517">Gloomhaven: Adventure Tokens – Sarcophagus</boardgameaccessory>
# <boardgameaccessory objectid="306374">Gloomhaven: Adventure Tokens – Shelf</boardgameaccessory>
# <boardgameaccessory objectid="287230">Gloomhaven: Adventure Tokens – Spike Pit</boardgameaccessory>
# <boardgameaccessory objectid="288416">Gloomhaven: Adventure Tokens – Stairs</boardgameaccessory>
# <boardgameaccessory objectid="306516">Gloomhaven: Adventure Tokens – Stone Pillar</boardgameaccessory>
# <boardgameaccessory objectid="287231">Gloomhaven: Adventure Tokens – Stump</boardgameaccessory>
# <boardgameaccessory objectid="287229">Gloomhaven: Adventure Tokens – Table</boardgameaccessory>
# <boardgameaccessory objectid="306514">Gloomhaven: Adventure Tokens – Totem</boardgameaccessory>
# <boardgameaccessory objectid="288417">Gloomhaven: Adventure Tokens – Wall Section</boardgameaccessory>
# <boardgameexpansion objectid="312632">Gloomhaven: Assault on the Morning Star (Promo Scenario)</boardgameexpansion>
# <boardgameexpansion objectid="310777">Gloomhaven: Beyond the End of the World (Promo Scenario)</boardgameexpansion>
# <boardgameaccessory objectid="272787">Gloomhaven: Broken Token Character Trays</boardgameaccessory>
# <boardgameaccessory objectid="272783">Gloomhaven: Broken Token Organizer</boardgameaccessory>
# <boardgameaccessory objectid="275029">Gloomhaven: Broken Token Organizer – Extra Dividers</boardgameaccessory>
# <boardgameaccessory objectid="280078">Gloomhaven: Broken Token Organizer – Forgotten Circles Upgrade</boardgameaccessory>
# <boardgameaccessory objectid="272784">Gloomhaven: Broken Token Tuck Boxes</boardgameaccessory>
# <boardgameaccessory objectid="393273">Gloomhaven: Challenge Coin</boardgameaccessory>
# <boardgameaccessory objectid="282059">Gloomhaven: Crafting Kingdoms Playmats</boardgameaccessory>
# <boardgameaccessory objectid="308555">Gloomhaven: E-Raptor Insert</boardgameaccessory>
# <boardgameexpansion objectid="380753">Gloomhaven: Envelope X Reward</boardgameexpansion>
# <boardgameaccessory objectid="261980">Gloomhaven: Folded Space Insert</boardgameaccessory>
# <boardgameexpansion objectid="250337">Gloomhaven: Forgotten Circles</boardgameexpansion>
# <boardgameaccessory objectid="367191">Gloomhaven: Forgotten Circles – Tower Rex Organizer</boardgameaccessory>
# <boardgameaccessory objectid="365880">Gloomhaven: Forgotten Circles – Tower Rex Organizer Upgrade</boardgameaccessory>
# <boardgameaccessory objectid="336186">Gloomhaven: Gaming Trunk Character's Tray</boardgameaccessory>
# <boardgameaccessory objectid="272804">Gloomhaven: Gloom Tavern Organizer</boardgameaccessory>
# <boardgameaccessory objectid="367868">Gloomhaven: Go7 Gaming Top Tray</boardgameaccessory>
# <boardgameaccessory objectid="250857">Gloomhaven: HP/XP Trackers</boardgameaccessory>
# <boardgameintegration objectid="291457">Gloomhaven: Jaws of the Lion</boardgameintegration>
# <boardgameaccessory objectid="261252">Gloomhaven: Laserox GloomBox Organizer</boardgameaccessory>
# <boardgameaccessory objectid="306362">Gloomhaven: Laserox Monster Bases</boardgameaccessory>
# <boardgameexpansion objectid="312635">Gloomhaven: Memories of Gloomhaven (Promo Scenario)</boardgameexpansion>
# <boardgameaccessory objectid="293088">Gloomhaven: Metal Coin Upgrade</boardgameaccessory>
# <boardgameaccessory objectid="250858">Gloomhaven: Miniatures</boardgameaccessory>
# <boardgameaccessory objectid="366336">Gloomhaven: Momo Monster Playmat</boardgameaccessory>
# <boardgameaccessory objectid="273547">Gloomhaven: Player Mat</boardgameaccessory>
# <boardgameexpansion objectid="236232">Gloomhaven: Removable Sticker Set</boardgameexpansion>
# <boardgameexpansion objectid="298195">Gloomhaven: Return of the Lost Cabal (Promo Scenario)</boardgameexpansion>
# <boardgameaccessory objectid="338418">Gloomhaven: Saim Lab Insert</boardgameaccessory>
# <boardgameimplementation objectid="390478">Gloomhaven: Second Edition</boardgameimplementation>
# <boardgameexpansion objectid="297586">Gloomhaven: Secrets of the Lost Cabal (Promo Scenario)</boardgameexpansion>
# <boardgameexpansion objectid="226868">Gloomhaven: Solo Scenarios</boardgameexpansion>
# <boardgameexpansion objectid="310773">Gloomhaven: The Catacombs of Chaos (Promo Scenario)</boardgameexpansion>
# <boardgameexpansion objectid="231934">Gloomhaven: The End of the World (Promo Scenario)</boardgameexpansion>
# <boardgameaccessory objectid="348625">Gloomhaven: The GiftForge Insert</boardgameaccessory>
# <boardgameexpansion objectid="300402">Gloomhaven: The Lucky Meeple (Promo Scenario)</boardgameexpansion>
# <boardgameexpansion objectid="310754">Gloomhaven: The Tower of Misfortune (Promo Scenario)</boardgameexpansion>
# <boardgameaccessory objectid="365831">Gloomhaven: Tower Rex Character Dashboard</boardgameaccessory>
# <boardgameaccessory objectid="365799">Gloomhaven: Tower Rex Dashboard</boardgameaccessory>
# <boardgameaccessory objectid="267166">Gloomhaven: Tower Rex Organizer</boardgameaccessory>
# <boardgameexpansion objectid="312638">Gloomhaven: Twilight of the Lost Cabal (Promo Scenario)</boardgameexpansion>
# <boardgameaccessory objectid="265296">Gloomhaven: WarBox Insert</boardgameaccessory>
# <boardgamemechanic objectid="2676">Grid Movement</boardgamemechanic>
# <boardgamepodcastepisode objectid="230935">GrogCast Season 6 Episode 1 &amp;ndash; Kickstarter Projects &amp;amp; Campaign Games</boardgamepodcastepisode>
# <boardgamemechanic objectid="2040">Hand Management</boardgamemechanic>
# <boardgamemechanic objectid="2026">Hexagon Grid</boardgamemechanic>
# <boardgamepodcastepisode objectid="253248">HLG 50: Roll &amp;amp; Write</boardgamepodcastepisode>
# <boardgamepublisher objectid="18852">Hobby World</boardgamepublisher>
# <boardgamepodcastepisode objectid="296349">HSG78: Gloomhaven - Legacy Adventure Board Game</boardgamepodcastepisode>
# <boardgameversion objectid="441836">Hungarian edition</boardgameversion>
# <boardgameversion objectid="448521">Italian edition</boardgameversion>
# <boardgameversion objectid="554544">Japanese edition</boardgameversion>
# <boardgamepodcastepisode objectid="256138">JTRPodcast 044 – Game Rewind September 2017</boardgamepodcastepisode>
# <boardgamepublisher objectid="8291">Korea Boardgames</boardgamepublisher>
# <boardgameversion objectid="455813">Korean edition</boardgameversion>
# <boardgamepodcastepisode objectid="275360">Laughing at Negative Reviews of the BGG Top 10 Games</boardgamepodcastepisode>
# <boardgamemechanic objectid="2824">Legacy Game</boardgamemechanic>
# <boardgamepodcastepisode objectid="241700">Limited Play Time: Top Ten Games of ALL TIME</boardgamepodcastepisode>
# <boardgamemechanic objectid="2975">Line of Sight</boardgamemechanic>
# <boardgamepodcastepisode objectid="199630">Los problemas del primer mundo jugón</boardgamepodcastepisode>
# <boardgameartist objectid="78961">Josh T. McDowell</boardgameartist>
# <boardgamefamily objectid="24281">Mechanism: Campaign Games</boardgamefamily>
# <boardgamefamily objectid="25404">Mechanism: Legacy</boardgamefamily>
# <boardgamecategory objectid="1047">Miniatures</boardgamecategory>
# <boardgamefamily objectid="75241">Misc: Forteller Audio Narration</boardgamefamily>
# <boardgamefamily objectid="78680">Misc: Made by Panda</boardgamefamily>
# <boardgamepodcastepisode objectid="161966">MOBG Podcast 37: 500 Games of Summer.</boardgamepodcastepisode>
# <boardgamemechanic objectid="2011">Modular Board</boardgamemechanic>
# <boardgamemechanic objectid="3099">Multi-Use Cards</boardgamemechanic>
# <boardgamepublisher objectid="23756">MYBG Co., Ltd.</boardgamepublisher>
# <boardgameartist objectid="84269">Alvaro Nebot</boardgameartist>
# <boardgamemechanic objectid="2846">Once-Per-Game Abilities</boardgamemechanic>
# <boardgamefamily objectid="5666">Players: Games with Solitaire Rules</boardgamefamily>
# <boardgamepodcastepisode objectid="247131">Podcast #10 with Uwe Eickert</boardgamepodcastepisode>
# <boardgameversion objectid="424523">Polish edition</boardgameversion>
# <boardgameversion objectid="507879">Portuguese edition</boardgameversion>
# <boardgamepodcastepisode objectid="328478">RA episode 026 Gloomhaven Ahead!</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="355228">RDTN Episode 201: Isaac Childres Interview,  Gloomhaven: Jaws of the Lion</boardgamepodcastepisode>
# <boardgamemechanic objectid="2028">Role Playing</boardgamemechanic>
# <boardgamepodcastepisode objectid="285233">Root, Updates, News, and a myriad of Kickstarters</boardgamepodcastepisode>
# <boardgameversion objectid="388684">Russian edition</boardgameversion>
# <boardgamemechanic objectid="2822">Scenario / Mission / Campaign Game</boardgamemechanic>
# <boardgamemechanic objectid="2020">Simultaneous Action Selection</boardgamemechanic>
# <boardgamemechanic objectid="2819">Solo / Solitaire Game</boardgamemechanic>
# <boardgameversion objectid="447572">Spanish edition, first printing</boardgameversion>
# <boardgameversion objectid="569024">Spanish edition, second printing</boardgameversion>
# <boardgamepodcastepisode objectid="272671">Strange Assembly 252 - Game of the Year 2017-2018</boardgamepodcastepisode>
# <boardgamesubdomain objectid="5497">Strategy Games</boardgamesubdomain>
# <boardgamemechanic objectid="3100">Tags</boardgamemechanic>
# <boardgamepodcastepisode objectid="212865">TGT 054: Gaming Trends</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="213593">TGT 056: Gaming Tables</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="214708">TGT 059: Fiddly Bits</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="214962">TGT 060: Ancient Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="225508">TGT 072: 2017 Favorites</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="229267">TGT 077: Running and Playing Convention Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="230652">TGT 079: The 10×10 Challenge</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="232538">TGT 082: Games Requiring Continued Investment</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="233106">TGT 083: Adventure Story Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="234659">TGT 086: Are There Too Many Games?</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="236731">TGT 089: Playing For Fun</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="241070">TGT 092: Kickstarter</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="243832">TGT 095: Two Plus Players at Two Players</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="244448">TGT 096: Origins 2018</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="245158">TGT 097: Asymmetrical Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="254579">TGT 105 On Topic: Generic Settings</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="268961">TGT 111 On Topic: Complicated Games</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="268959">TGT 113 On Topic: Replayability</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="271574">TGT 120 On Topic: Organized Play</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="273080">TGT 122: $250 Game Collection</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="234042">The 2018 Sniffies Awards – An FFSSBGS Special</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="204308">The Dice Men Cometh – Episode 160</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="204921">The Dice Men Cometh – Episode 162</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="224344">The Dice Men Cometh – Episode 194</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="225509">The Dice Men Cometh – Episode 195</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="233234">The Dice Men Cometh – Episode 204</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="227879">The Game Pit Podcast - Episode 106: 10 x 10 Challenge 2018</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="204463">THE GAME PIT: EPISODE 82 - PICKING OVER THE BONES</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="241831">The Good the Board and the Classified Episode 165 Tabletop Taxonomy</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="203180">The Good The Board and The Expedition: Episode 104 "Campaign Games"</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="203178">The Good The Board and The Gamers Say the Darndest Things: Ep 106 "Gamer Quotes"</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="203181">The Good The Board and The Get Your Stuff Together Jonathan:  Ep 103 "Coin Games"</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="203176">THe Good The Board and The Redeemed: Episdoe 108 "Second Chance Games"</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="161999">The Seventh Peg Episode 20- Isaac Childres</boardgamepodcastepisode>
# <boardgamesubdomain objectid="5496">Thematic Games</boardgamesubdomain>
# <boardgamepodcastepisode objectid="203098">There's No Such Thing as a Cool Cup</boardgamepodcastepisode>
# <boardgamemechanic objectid="2015">Variable Player Powers</boardgamemechanic>
# <boardgamepodcastepisode objectid="200154">Vox Republica 138: Havens Of Gloooooom</boardgamepodcastepisode>
# <boardgamepodcastepisode objectid="161302">What Did You Play This Week Podcast Thing Week 41!!! Avalanche at Yeti Mountain Preview, NY 1901 Review</boardgamepodcastepisode>
# <boardgameintegration inbound="true" objectid="295770">Frosthaven</boardgameintegration>
# <boardgameintegration inbound="true" objectid="291457">Gloomhaven: Jaws of the Lion</boardgameintegration>
# <poll name="suggested_numplayers" title="User Suggested Number of Players" totalvotes="1501">
# <results numplayers="1">
# <result numvotes="143" value="Best"/>
# <result numvotes="643" value="Recommended"/>
# <result numvotes="356" value="Not Recommended"/>
# </results>
# <results numplayers="2">
# <result numvotes="373" value="Best"/>
# <result numvotes="822" value="Recommended"/>
# <result numvotes="89" value="Not Recommended"/>
# </results>
# <results numplayers="3">
# <result numvotes="736" value="Best"/>
# <result numvotes="501" value="Recommended"/>
# <result numvotes="37" value="Not Recommended"/>
# </results>
# <results numplayers="4">
# <result numvotes="457" value="Best"/>
# <result numvotes="597" value="Recommended"/>
# <result numvotes="159" value="Not Recommended"/>
# </results>
# <results numplayers="4+">
# <result numvotes="6" value="Best"/>
# <result numvotes="50" value="Recommended"/>
# <result numvotes="836" value="Not Recommended"/>
# </results>
# </poll>
# <poll name="language_dependence" title="Language Dependence" totalvotes="67">
# <results>
# <result level="1" numvotes="1" value="No necessary in-game text"/>
# <result level="2" numvotes="0" value="Some necessary text - easily memorized or small crib sheet"/>
# <result level="3" numvotes="2" value="Moderate in-game text - needs crib sheet or paste ups"/>
# <result level="4" numvotes="46" value="Extensive use of text - massive conversion needed to be playable"/>
# <result level="5" numvotes="18" value="Unplayable in another language"/>
# </results>
# </poll>
# <poll name="suggested_playerage" title="User Suggested Player Age" totalvotes="318">
# <results>
# <result numvotes="5" value="2"/>
# <result numvotes="0" value="3"/>
# <result numvotes="0" value="4"/>
# <result numvotes="0" value="5"/>
# <result numvotes="0" value="6"/>
# <result numvotes="7" value="8"/>
# <result numvotes="42" value="10"/>
# <result numvotes="89" value="12"/>
# <result numvotes="147" value="14"/>
# <result numvotes="22" value="16"/>
# <result numvotes="3" value="18"/>
# <result numvotes="3" value="21 and up"/>
# </results>
# </poll>
# </boardgame>
# </boardgames>

# %%
game_name = soup.find("name", {"primary": "true", "sortindex": "1"}).text

# here I'm creating a variable that will return the name of the game
# that is inside the information
# <name primary="true" sortindex="1">Gloomhaven</name>
# in the dictionary "name", with the keys "primary" and "sortindex"
# and I'll introduce in the future in a new variable

poll_section = soup.find("poll")

# After a search inside of the content I found that the relevant
# information that I was going to use was in the section named "poll"
# that contains information about the votes used to decide the values
# inside "best players" and "minimum age", in the data frame "bgg"

poll_section
# Out:
# <poll name="suggested_numplayers" title="User Suggested Number of Players" totalvotes="1501">
# <results numplayers="1">
# <result numvotes="143" value="Best"/>
# <result numvotes="643" value="Recommended"/>
# <result numvotes="356" value="Not Recommended"/>
# </results>
# <results numplayers="2">
# <result numvotes="373" value="Best"/>
# <result numvotes="822" value="Recommended"/>
# <result numvotes="89" value="Not Recommended"/>
# </results>
# <results numplayers="3">
# <result numvotes="736" value="Best"/>
# <result numvotes="501" value="Recommended"/>
# <result numvotes="37" value="Not Recommended"/>
# </results>
# <results numplayers="4">
# <result numvotes="457" value="Best"/>
# <result numvotes="597" value="Recommended"/>
# <result numvotes="159" value="Not Recommended"/>
# </results>
# <results numplayers="4+">
# <result numvotes="6" value="Best"/>
# <result numvotes="50" value="Recommended"/>
# <result numvotes="836" value="Not Recommended"/>
# </results>
# </poll>

# %%
gloomhaven_votes = []

# After it I created a new list to put inside the result of making
#a for loop of the results in the section "poll"


for poll_result in poll_section.find_all("results"):
    numplayers = poll_result.get("numplayers", "")
    # first obtaining the number of players "1-4+" with the method
    # get, that will take the values inside the key "numplayers",
    # inside the dictionary poll_result
    
    for result in poll_result.find_all("result"):
        value = result.get("value", "")
        numvotes = result.get("numvotes", "")
    # Inside the loop I had to make another iteration to obtain 
    # inside "poll result" all values that contain the key "value"
    # and "numvotes"
        
        
        gloomhaven_votes.append({
            "game_name": game_name, # Here is the name that I extracted before
            "num_players": numplayers,
            "value": value,
            "num_votes": numvotes})
        # And then append all this values inside "gloomhaven_votes" 

gloomhaven = pd.DataFrame(gloomhaven_votes)
# finally create a "DataFrame" with all the information appended in the list

gloomhaven
# Out:
#      game_name num_players            value num_votes
# 0   Gloomhaven           1             Best       143
# 1   Gloomhaven           1      Recommended       643
# 2   Gloomhaven           1  Not Recommended       356
# 3   Gloomhaven           2             Best       373
# 4   Gloomhaven           2      Recommended       822
# 5   Gloomhaven           2  Not Recommended        89
# 6   Gloomhaven           3             Best       736
# 7   Gloomhaven           3      Recommended       501
# 8   Gloomhaven           3  Not Recommended        37
# 9   Gloomhaven           4             Best       457
# 10  Gloomhaven           4      Recommended       597
# 11  Gloomhaven           4  Not Recommended       159
# 12  Gloomhaven          4+             Best         6
# 13  Gloomhaven          4+      Recommended        50
# 14  Gloomhaven          4+  Not Recommended       836

# %%
# After this, to avoid to repeat the same process with the other 9 urls
# I'm going to create a function that will do the process with each url

def extract_votes(url):
    # first make the request and obtain the xml
    response = requests.get(url)
    xml_data = response.text
    
    # then use the method "beautifulsoup" to make it more readable
    soup = BeautifulSoup(xml_data, "xml")
    
    # find the "name" of the game inside the text and save inside the variable game_name
    game_name = soup.find("name", {"primary": "true", "sortindex": "1"}).text

    # Find the section "poll" where is all the information about votes
    poll_section = soup.find("poll")
    
    # create a list to append the results in the "poll.section" dictionary
    top_ten_votes = []

    # iterate in the "poll_section" to extract the values for "numplayers"
    for poll_result in poll_section.find_all("results"):
        # save the values inside "numplayers"
        numplayers = poll_result.get("numplayers", "")
        
        # iterate inside the poll_result to extract the values for the keys
        # "value" and "numvotes"
        for result in poll_result.find_all("result"):
            # save the values inside "value" and "numvotes"
            value = result.get("value", "")
            numvotes = result.get("numvotes", "")
            
            # create a dictionario where append all the values of the previous iterations
            top_ten_votes.append({
                "game_name": game_name, # here save the name of the game, obtained before
                "num_players": numplayers,
                "value": value,
                "num_votes": numvotes
            })

    # create a Data Frame with all the extracted information
    df = pd.DataFrame(top_ten_votes)
    
    return df

urls = ["https://api.geekdo.com/xmlapi/boardgame/174430/",
    "https://api.geekdo.com/xmlapi/boardgame/161936/",
    "https://api.geekdo.com/xmlapi/boardgame/224517/",
    "https://api.geekdo.com/xmlapi/boardgame/167791/",
    "https://api.geekdo.com/xmlapi/boardgame/233078/",
    "https://api.geekdo.com/xmlapi/boardgame/291457/",
    "https://api.geekdo.com/xmlapi/boardgame/220308/",
    "https://api.geekdo.com/xmlapi/boardgame/187645/",
    "https://api.geekdo.com/xmlapi/boardgame/182028/",
    "https://api.geekdo.com/xmlapi/boardgame/115746/"]

# here I create a new list that will have all the urls that I will use inside the function


# Crear un DataFrame vacío para almacenar los resultados de todas las URLs
all_votes_df = pd.DataFrame()

# the next step will be create a new object that will create the final DF with all the information extracted

# Iterar sobre las URLs y agregar los resultados al DataFrame general
for url in urls:
    df = extract_votes(url)
    all_votes_df = pd.concat([all_votes, df], ignore_index=True)

# finally create a new loop to extract the url from the list of urls, to use
# the function on each one.
# and concatenate every new votes information in the final DF "all_votes_df".
# ignore_index=True will reindex the "all_votes_df" with the new information until the iteration finish


all_votes_df
# Out:
#                            game_name num_players            value num_votes
# 0                         Gloomhaven           1             Best       143
# 1                         Gloomhaven           1      Recommended       643
# 2                         Gloomhaven           1  Not Recommended       356
# 3                         Gloomhaven           2             Best       373
# 4                         Gloomhaven           2      Recommended       822
# ..                               ...         ...              ...       ...
# 169  War of the Ring: Second Edition           4      Recommended       125
# 170  War of the Ring: Second Edition           4  Not Recommended       198
# 171  War of the Ring: Second Edition          4+             Best         1
# 172  War of the Ring: Second Edition          4+      Recommended         3
# 173  War of the Ring: Second Edition          4+  Not Recommended       271
#
# [174 rows x 4 columns]

# %%
all_votes_df.to_csv('data/top_ten_votes.csv')

# this part exports all the changes to a new ".csv" file
